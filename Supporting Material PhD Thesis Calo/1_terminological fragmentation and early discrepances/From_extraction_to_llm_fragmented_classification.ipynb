# %%
import pandas as pd

# %%
# !pip install newspaper3k==0.2.8
# Out:
# Collecting newspaper3k==0.2.8
#   Downloading newspaper3k-0.2.8-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /usr/local/lib/python3.11/dist-packages (from newspaper3k==0.2.8) (4.12.3)
# Requirement already satisfied: Pillow>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from newspaper3k==0.2.8) (11.1.0)
# Requirement already satisfied: PyYAML>=3.11 in /usr/local/lib/python3.11/dist-packages (from newspaper3k==0.2.8) (6.0.2)
# Collecting cssselect>=0.9.2 (from newspaper3k==0.2.8)
#   Downloading cssselect-1.2.0-py2.py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: lxml>=3.6.0 in /usr/local/lib/python3.11/dist-packages (from newspaper3k==0.2.8) (5.3.0)
# Requirement already satisfied: nltk>=3.2.1 in /usr/local/lib/python3.11/dist-packages (from newspaper3k==0.2.8) (3.9.1)
# Requirement already satisfied: requests>=2.10.0 in /usr/local/lib/python3.11/dist-packages (from newspaper3k==0.2.8) (2.32.3)
# Collecting feedparser>=5.2.1 (from newspaper3k==0.2.8)
#   Downloading feedparser-6.0.11-py3-none-any.whl.metadata (2.4 kB)
# Collecting tldextract>=2.0.1 (from newspaper3k==0.2.8)
#   Downloading tldextract-5.1.3-py3-none-any.whl.metadata (11 kB)
# Collecting feedfinder2>=0.0.4 (from newspaper3k==0.2.8)
#   Downloading feedfinder2-0.0.4.tar.gz (3.3 kB)
#   Preparing metadata (setup.py) ... done
# Collecting jieba3k>=0.35.1 (from newspaper3k==0.2.8)
#   Downloading jieba3k-0.35.1.zip (7.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 47.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.11/dist-packages (from newspaper3k==0.2.8) (2.8.2)
# Collecting tinysegmenter==0.3 (from newspaper3k==0.2.8)
#   Downloading tinysegmenter-0.3.tar.gz (16 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4>=4.4.1->newspaper3k==0.2.8) (2.6)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from feedfinder2>=0.0.4->newspaper3k==0.2.8) (1.17.0)
# Collecting sgmllib3k (from feedparser>=5.2.1->newspaper3k==0.2.8)
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk>=3.2.1->newspaper3k==0.2.8) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk>=3.2.1->newspaper3k==0.2.8) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk>=3.2.1->newspaper3k==0.2.8) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk>=3.2.1->newspaper3k==0.2.8) (4.67.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.10.0->newspaper3k==0.2.8) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.10.0->newspaper3k==0.2.8) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.10.0->newspaper3k==0.2.8) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.10.0->newspaper3k==0.2.8) (2024.12.14)
# Collecting requests-file>=1.4 (from tldextract>=2.0.1->newspaper3k==0.2.8)
#   Downloading requests_file-2.1.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: filelock>=3.0.8 in /usr/local/lib/python3.11/dist-packages (from tldextract>=2.0.1->newspaper3k==0.2.8) (3.17.0)
# Downloading newspaper3k-0.2.8-py3-none-any.whl (211 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.1/211.1 kB 13.3 MB/s eta 0:00:00
# Downloading cssselect-1.2.0-py2.py3-none-any.whl (18 kB)
# Downloading feedparser-6.0.11-py3-none-any.whl (81 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.3/81.3 kB 5.7 MB/s eta 0:00:00
# Downloading tldextract-5.1.3-py3-none-any.whl (104 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.9/104.9 kB 7.7 MB/s eta 0:00:00
# Downloading requests_file-2.1.0-py2.py3-none-any.whl (4.2 kB)
# Building wheels for collected packages: tinysegmenter, feedfinder2, jieba3k, sgmllib3k
#   Building wheel for tinysegmenter (setup.py) ... done
#   Created wheel for tinysegmenter: filename=tinysegmenter-0.3-py3-none-any.whl size=13539 sha256=ef8bca897c7d9a04b916a70e91ab4374797ccc83174741558dbfd139d43c1f60
#   Stored in directory: /root/.cache/pip/wheels/fc/ab/f8/cce3a9ae6d828bd346be695f7ff54612cd22b7cbd7208d68f3
#   Building wheel for feedfinder2 (setup.py) ... done
#   Created wheel for feedfinder2: filename=feedfinder2-0.0.4-py3-none-any.whl size=3342 sha256=032a44c93b410d22aa693e2be500eb6f65bb8e0270d5664e4441c9aa64160f46
#   Stored in directory: /root/.cache/pip/wheels/80/d5/72/9cd9eccc819636436c6a6e59c22a0fb1ec167beef141f56491
#   Building wheel for jieba3k (setup.py) ... done
#   Created wheel for jieba3k: filename=jieba3k-0.35.1-py3-none-any.whl size=7398379 sha256=ab032288546aec08fff84a66893f3ef91b76002892fd0b69e938c51ace576bc7
#   Stored in directory: /root/.cache/pip/wheels/3a/a1/46/8e68055c1713f9c4598774c15ad0541f26d5425ee7423b6493
#   Building wheel for sgmllib3k (setup.py) ... done
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6047 sha256=2862499103d96dbc6ad28550fb017cb03c202a9568d77e41e3999795742a455d
#   Stored in directory: /root/.cache/pip/wheels/3b/25/2a/105d6a15df6914f4d15047691c6c28f9052cc1173e40285d03
# Successfully built tinysegmenter feedfinder2 jieba3k sgmllib3k
# Installing collected packages: tinysegmenter, sgmllib3k, jieba3k, feedparser, cssselect, requests-file, feedfinder2, tldextract, newspaper3k
# Successfully installed cssselect-1.2.0 feedfinder2-0.0.4 feedparser-6.0.11 jieba3k-0.35.1 newspaper3k-0.2.8 requests-file-2.1.0 sgmllib3k-1.0.0 tinysegmenter-0.3 tldextract-5.1.3

# %%
# !pip install lxml[html_clean]
# Out:
# Requirement already satisfied: lxml[html_clean] in /usr/local/lib/python3.11/dist-packages (5.3.0)
# Collecting lxml-html-clean (from lxml[html_clean])
#   Downloading lxml_html_clean-0.4.1-py3-none-any.whl.metadata (2.4 kB)
# Downloading lxml_html_clean-0.4.1-py3-none-any.whl (14 kB)
# Installing collected packages: lxml-html-clean
# Successfully installed lxml-html-clean-0.4.1

# %%
from openai import OpenAI
import pandas as pd

# Your API token and base URL
client = OpenAI(
    api_key='eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....oBUY9bRglAgpHGTl6LVNVL839DjDPn6U2dCna2QQGPk',
    base_url="https://api-gpt.jrc.ec.europa.eu/v1"
)

# Load your dataset
df = pd.read_csv('marco_ds_c.150_newspaper_no_duplicates.csv')

def summarize_text(text):
    try:
        chat_completion = client.chat.completions.create(
            model="llama-3.3-70b-instruct",
            messages=[
                {"role": "system", "content": "You are a helpful and harmless AI assistant."},
                {"role": "user", "content": f"Please provide a concise summary of the following text: {text}"}
            ],
            stream=False,
            temperature=0.8
        )
        summary = chat_completion.choices[0].message.content
        return summary
    except Exception as e:
        print(f"Error summarizing text: {e}")
        return ""  # Return an empty string in case of error

# Apply the function to the "text" column
df['summary'] = df['text'].apply(summarize_text)

# Print the DataFrame with the new column
print(df)
# Out:
#       globaleventid              event_date    actor_1_name  \
# 0        1033011463  2022-03-10 00:00:00+00     NORTH KOREA
# 1        1033011467  2022-03-10 00:00:00+00     NORTH KOREA
# 2        1036864022  2022-03-30 00:00:00+00  UNITED KINGDOM
# 3        1036864390  2022-03-30 00:00:00+00         RUSSIAN
# 4        1035836120  2022-03-25 00:00:00+00       SCIENTIST
# ...             ...                     ...             ...
# 1035     1035390005  2022-03-23 00:00:00+00             NaN
# 1036     1035747117  2022-03-24 00:00:00+00       GREENLAND
# 1037     1035457594  2022-03-23 00:00:00+00             NaN
# 1038     1031210742  2022-03-01 00:00:00+00         COMPANY
# 1039     1033390807  2022-03-12 00:00:00+00         UKRAINE
#
#      actor_1_country_code actor_1_type_code    actor_2_name  \
# 0                     PRK               NaN             NaN
# 1                     PRK               NaN   UNITED STATES
# 2                     GBR               NaN             NaN
# 3                     RUS               NaN        CIVILIAN
# 4                     NaN               CVL         FLORIDA
# ...                   ...               ...             ...
# 1035                  NaN               NaN   UNITED STATES
# 1036                  DNK               NaN             NaN
# 1037                  NaN               NaN        INDUSTRY
# 1038                  NaN               BUS         UKRAINE
# 1039                  UKR               NaN  VLADIMIR PUTIN
#
#      actor_2_country_code actor_2_type_code  event_code  event_base_code  \
# 0                     NaN               NaN         173              173
# 1                     USA               NaN          20               20
# 2                     NaN               NaN          10               10
# 3                     NaN               CVL          80               80
# 4                     USA               NaN          12               12
# ...                   ...               ...         ...              ...
# 1035                  USA               NaN          84               84
# 1036                  NaN               NaN          70               70
# 1037                  NaN               BUS          42               42
# 1038                  UKR               NaN         111              111
# 1039                  RUS               GOV          51               51
#
#       event_root_code                                         source_url  \
# 0                  17  https://tribune.com.pk/story/2347267/north-kor...
# 1                   2  https://www.nbcnews.com/news/world/north-korea...
# 2                   1  https://www.cnn.com/2022/03/30/politics/clinto...
# 3                   8  https://news.yahoo.com/putin-promised-retreat-...
# 4                   1  https://www.theguardian.com/world/2022/mar/25/...
# ...               ...                                                ...
# 1035                8  https://www.kob.com/albuquerque-news/albuquerq...
# 1036                7  https://www.enn.com/articles/69981-internation...
# 1037                4  http://www.parabolicarc.com/2022/03/23/micro-g...
# 1038               11  https://www.theregister.com/2022/03/01/maxar_s...
# 1039                5  https://techstory.in/ukrainian-flag-will-launc...
#
#      retrieved_words                                              title  \
# 0          satellite  North Korea to launch satellites to monitor US...
# 1          satellite  North Korea says it plans to launch satellites...
# 2                gps  Hillary Clinton campaign and DNC fined by FEC ...
# 3          satellite  Putin Promised to Retreat from Kyiv—but What D...
# 4          satellite  Satellite data shows entire Conger ice shelf h...
# ...              ...                                                ...
# 1035             gps  Albuquerque teen accused of 2 murders released...
# 1036       satellite  International Sea Level Satellite Takes Over F...
# 1037       satellite                                                NaN
# 1038       satellite  The satellite giant bringing global crisis int...
# 1039          spacex                                                NaN
#
#                                                    text  \
# 0     North Korean leader Kim Jong Un inspects North...
# 1     SEOUL, South Korea — North Korea will launch a...
# 2     Washington CNN —\n\nFederal election regulator...
# 3     Some Russian military vehicles around Ukraine’...
# 4     An ice shelf about the size of Rome has comple...
# ...                                                 ...
# 1035  ALBUQUERQUE, N.M. – Adrian Avila, who is accus...
# 1036  Sentinel-6 Michael Freilich, the newest additi...
# 1037                                                NaN
# 1038  As Russia's invasion of Ukraine continues, the...
# 1039                                                NaN
#
#                                                 summary
# 0     Here is a concise summary of the text:\n\nNort...
# 1     Here is a concise summary of the text:\n\nNort...
# 2     The Federal Election Commission (FEC) has fine...
# 3     Here is a concise summary of the text:\n\nSate...
# 4     Here is a concise summary of the text:\n\nThe ...
# ...                                                 ...
# 1035  Adrian Avila, accused of killing two people in...
# 1036  The Sentinel-6 Michael Freilich satellite has ...
# 1037  There is no text to summarize. Please provide ...
# 1038  Here is a concise summary of the text:\n\nMaxa...
# 1039  There is no text to summarize. The input "nan"...
#
# [1040 rows x 16 columns]

# %%
from openai import OpenAI
import pandas as pd
import re
import time

# Your API token and base URL
client = OpenAI(
    api_key='eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....oBUY9bRglAgpHGTl6LVNVL839DjDPn6U2dCna2QQGPk',
    base_url="https://api-gpt.jrc.ec.europa.eu/v1"
)

# Load your dataset
df = pd.read_csv('marco_ds_c.150_newspaper_with_attack_type.csv')

# Check if the 'attack_type' column exists. If not, create it with empty strings
if 'attack_type' not in df.columns:
    df['attack_type'] = ''  # Initialize with empty strings

# Check if the 'summary' column exists. If not, create it with empty strings
if 'summary' not in df.columns:
    df['summary'] = ''  # Initialize with empty strings

def categorize_attack_type(text):
    try:
        chat_completion = client.chat.completions.create(
            model="llama-3.3-70b-instruct",
            messages=[
                {"role": "system", "content": "You are a helpful and harmless AI assistant."},
                {"role": "user", "content": f"""
Categorize the attack type of the following text: {text}
Only provide the attack type, without any additional context or explanation.
For example, instead of saying "The attack type of the text is Phishing", simply respond with "Phishing".
"""}
            ],
            stream=False,
            temperature=0.8
        )
        attack_type = chat_completion.choices[0].message.content.strip()

        # Remove contextual phrases using regex (optional)
        attack_type = re.sub(r"the attack type (?:of the text )?is\s*", "", attack_type, flags=re.IGNORECASE)
        attack_type = attack_type.strip()  # Strip again to remove any leading/trailing spaces

        return attack_type
    except Exception as e:
        if "429" in str(e):  # Check for rate limit error
            print("Rate limit exceeded. Waiting for 60 seconds...")
            time.sleep(60)  # Wait for 60 seconds
            return categorize_attack_type(text)  # Retry the request
        else:
            print(f"Error categorizing attack type: {e}")
            return ""

def summarize_text(text):
    try:
        chat_completion = client.chat.completions.create(
            model="llama-3.3-70b-instruct",
            messages=[
                {"role": "system", "content": "You are a helpful and harmless AI assistant."},
                {"role": "user", "content": f"Please provide a concise summary of the following text: {text}"}
            ],
            stream=False,
            temperature=0.8
        )
        summary = chat_completion.choices[0].message.content
        return summary
    except Exception as e:
        if "429" in str(e):  # Check for rate limit error
            print("Rate limit exceeded. Waiting for 60 seconds...")
            time.sleep(60)  # Wait for 60 seconds
            return summarize_text(text)  # Retry the request
        else:
            print(f"Error summarizing text: {e}")
            return ""

# Apply the functions only to rows where the respective columns are empty
df.loc[df['attack_type'] == '', 'attack_type'] = df.loc[df['attack_type'] == '', 'text'].apply(categorize_attack_type)
df.loc[df['summary'] == '', 'summary'] = df.loc[df['summary'] == '', 'text'].apply(summarize_text)

# Print the DataFrame with the new columns
print(df)
# Out:
# Rate limit exceeded. Waiting for 60 seconds...
# Rate limit exceeded. Waiting for 60 seconds...
# Rate limit exceeded. Waiting for 60 seconds...
# Rate limit exceeded. Waiting for 60 seconds...
# Rate limit exceeded. Waiting for 60 seconds...
# Rate limit exceeded. Waiting for 60 seconds...
# Rate limit exceeded. Waiting for 60 seconds...
# Rate limit exceeded. Waiting for 60 seconds...
# Rate limit exceeded. Waiting for 60 seconds...
# Rate limit exceeded. Waiting for 60 seconds...
# Rate limit exceeded. Waiting for 60 seconds...
# Rate limit exceeded. Waiting for 60 seconds...
# Rate limit exceeded. Waiting for 60 seconds...
# Rate limit exceeded. Waiting for 60 seconds...
# Rate limit exceeded. Waiting for 60 seconds...
# Rate limit exceeded. Waiting for 60 seconds...
# Rate limit exceeded. Waiting for 60 seconds...
#       globaleventid              event_date    actor_1_name  \
# 0        1033011463  2022-03-10 00:00:00+00     NORTH KOREA
# 1        1033011467  2022-03-10 00:00:00+00     NORTH KOREA
# 2        1036864022  2022-03-30 00:00:00+00  UNITED KINGDOM
# 3        1036864390  2022-03-30 00:00:00+00         RUSSIAN
# 4        1035836120  2022-03-25 00:00:00+00       SCIENTIST
# ...             ...                     ...             ...
# 1035     1035390005  2022-03-23 00:00:00+00             NaN
# 1036     1035747117  2022-03-24 00:00:00+00       GREENLAND
# 1037     1035457594  2022-03-23 00:00:00+00             NaN
# 1038     1031210742  2022-03-01 00:00:00+00         COMPANY
# 1039     1033390807  2022-03-12 00:00:00+00         UKRAINE
#
#      actor_1_country_code actor_1_type_code    actor_2_name  \
# 0                     PRK               NaN             NaN
# 1                     PRK               NaN   UNITED STATES
# 2                     GBR               NaN             NaN
# 3                     RUS               NaN        CIVILIAN
# 4                     NaN               CVL         FLORIDA
# ...                   ...               ...             ...
# 1035                  NaN               NaN   UNITED STATES
# 1036                  DNK               NaN             NaN
# 1037                  NaN               NaN        INDUSTRY
# 1038                  NaN               BUS         UKRAINE
# 1039                  UKR               NaN  VLADIMIR PUTIN
#
#      actor_2_country_code actor_2_type_code  event_code  event_base_code  \
# 0                     NaN               NaN         173              173
# 1                     USA               NaN          20               20
# 2                     NaN               NaN          10               10
# 3                     NaN               CVL          80               80
# 4                     USA               NaN          12               12
# ...                   ...               ...         ...              ...
# 1035                  USA               NaN          84               84
# 1036                  NaN               NaN          70               70
# 1037                  NaN               BUS          42               42
# 1038                  UKR               NaN         111              111
# 1039                  RUS               GOV          51               51
#
#       event_root_code                                         source_url  \
# 0                  17  https://tribune.com.pk/story/2347267/north-kor...
# 1                   2  https://www.nbcnews.com/news/world/north-korea...
# 2                   1  https://www.cnn.com/2022/03/30/politics/clinto...
# 3                   8  https://news.yahoo.com/putin-promised-retreat-...
# 4                   1  https://www.theguardian.com/world/2022/mar/25/...
# ...               ...                                                ...
# 1035                8  https://www.kob.com/albuquerque-news/albuquerq...
# 1036                7  https://www.enn.com/articles/69981-internation...
# 1037                4  http://www.parabolicarc.com/2022/03/23/micro-g...
# 1038               11  https://www.theregister.com/2022/03/01/maxar_s...
# 1039                5  https://techstory.in/ukrainian-flag-will-launc...
#
#      retrieved_words                                              title  \
# 0          satellite  North Korea to launch satellites to monitor US...
# 1          satellite  North Korea says it plans to launch satellites...
# 2                gps  Hillary Clinton campaign and DNC fined by FEC ...
# 3          satellite  Putin Promised to Retreat from Kyiv—but What D...
# 4          satellite  Satellite data shows entire Conger ice shelf h...
# ...              ...                                                ...
# 1035             gps  Albuquerque teen accused of 2 murders released...
# 1036       satellite  International Sea Level Satellite Takes Over F...
# 1037       satellite                                                NaN
# 1038       satellite  The satellite giant bringing global crisis int...
# 1039          spacex                                                NaN
#
#                                                    text  \
# 0     North Korean leader Kim Jong Un inspects North...
# 1     SEOUL, South Korea — North Korea will launch a...
# 2     Washington CNN —\n\nFederal election regulator...
# 3     Some Russian military vehicles around Ukraine’...
# 4     An ice shelf about the size of Rome has comple...
# ...                                                 ...
# 1035  ALBUQUERQUE, N.M. – Adrian Avila, who is accus...
# 1036  Sentinel-6 Michael Freilich, the newest additi...
# 1037                                                NaN
# 1038  As Russia's invasion of Ukraine continues, the...
# 1039                                                NaN
#
#                                             attack_type  \
# 0                                                  None
# 1     Cyber is not mentioned in the text, Ballistic ...
# 2                                        Disinformation
# 3                                  Conventional Warfare
# 4                                                  None
# ...                                                 ...
# 1035                            Physical/Violent Attack
# 1036                                               None
# 1037                           Insufficient Information
# 1038                                               None
# 1039                                     Non-applicable
#
#                                                 summary
# 0     Here is a concise summary of the text:\n\nNort...
# 1     Here is a concise summary of the text:\n\nNort...
# 2     The Federal Election Commission (FEC) has fine...
# 3     Here is a concise summary of the text:\n\nSate...
# 4     Here is a concise summary of the article:\n\nT...
# ...                                                 ...
# 1035  Adrian Avila, accused of killing two people in...
# 1036  The Sentinel-6 Michael Freilich satellite has ...
# 1037  There is no text to summarize. The input "nan"...
# 1038  Maxar is a commercial satellite company that p...
# 1039  There is no text to summarize. Please provide ...
#
# [1040 rows x 17 columns]
